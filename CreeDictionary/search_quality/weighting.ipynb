# %% [markdown]
# # Search feature weighting

# %% [markdown]
# As of early 2020, search ranking is done by an ad-hoc pairwise comparison function that may not even be transitive. We want to replace it with a more structured and analyzable approach that can accommodate multiple search features such as cosine vector distance and corpus frequency, and weight those features in some manner to produce a best fit for a relevance score to use for ranking results.
#
# The basic pieces are:
#   - Use occurrence of a search result in the search survey as a 0-or-1 relevance variable
#   - Model a relevance score from that using some fairly basic linear techniques
#   - Measure success by the three10 score: the mean percentage of the number of top-3 survey results that appear in the top 10 search results
#
# There are many possible improvements here, such as:
#   - Use occurence anywhere in sample, instead of top3 results only, for training
#   - More precise training data, e.g., relevance rankings of 1-5
#   - Handle homonyms in training data instead of matching purely on wordform text
#   - More training data in terms of scored results per query
#   - More features, e.g., tf-idf
#   - Higher quality features, e.g., better stopword filtering in vector computations
#   - Map features to have similar ranges and distributions to better allow comparison between them
#   - Separate training and test sets
#   - Fancier models
#   - Better evaluation functions, such as discounted cumulative gain
#
# *but having all the pieces together, even in this basic form, is already an improvement over the current search so let’s start there.*

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# Load some libraries. `analysis.py` contains some more python-y code that was extracted from some scratch jupyter notebooks once it was working ok.

# %%
import importlib

import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

import analysis

# If this is insufficient, there is also IPython.lib.deepreload
importlib.reload(analysis);

# %% [markdown]
# Here’s what the output of the `featuredump` management command looks like.

# %%
data = analysis.dataframe_from_featuredump('sample-features.json')
data
# Out:
#        target_language_keyword_match  query_wordform_edit_distance  \
# 0                            [about]                           NaN
# 1                            [about]                           NaN
# 2                            [about]                           NaN
# 3                            [about]                           NaN
# 4                            [about]                           NaN
# ...                              ...                           ...
# 123319                         [see]                           NaN
# 123320                        [they]                           NaN
# 123321                         [see]                           NaN
# 123322                        [they]                           NaN
# 123323                        [they]                           NaN
#
#        lemma_wordform_text is_preverb_match source_language_match  \
# 0                     itêw             None                  None
# 1                     itam             None                  None
# 2                   êtikwê             None                  None
# 3                   êtokwê             None                  None
# 4                   wîhtam             None                  None
# ...                    ...              ...                   ...
# 123319         nâtawâpamêw             None                  None
# 123320    pêyakôskânêsiwak             None                  None
# 123321        nâtawâpahtam             None                  None
# 123322   kakwâhyakêyatinwa             None                  None
# 123323     ahkwêhtawastêwa             None                  None
#
#                                               definitions        query  \
# 0       [[That's what he says to him., MD], [s/he says...        about
# 1       [[He speaks of it as so., MD], [s/he says thus...        about
# 2       [[I suppose., MD], [apparently, I guess, I sup...        about
# 3       [[Maybe; perhaps; I guess so., MD], [maybe, I ...        about
# 4       [[He tells about it., MD], [s/he tells about s...        about
# ...                                                   ...          ...
# 123319   [[s/he goes to see s.o., s/he fetches s.o., CW]]  they see us
# 123320  [[They are one group of them. E.g. Tribe or na...  they see us
# 123321   [[s/he goes to see s.t., s/he fetches s.t., CW]]  they see us
# 123322                   [[they are in vast numbers, CW]]  they see us
# 123323  [[they are piled in layers on top of one anoth...  they see us
#
#             wordform_text  webapp_sort_rank  wordform_length  \
# 0                    itêw                 1                4
# 1                    itam                 2                4
# 2                  êtikwê                 3                6
# 3                  êtokwê                 4                6
# 4                  wîhtam                 5                6
# ...                   ...               ...              ...
# 123319        nâtawâpamêw               503               11
# 123320   pêyakôskânêsiwak               504               16
# 123321       nâtawâpahtam               505               12
# 123322  kakwâhyakêyatinwa               506               17
# 123323    ahkwêhtawastêwa               507               15
#
#        source_language_affix_match  cosine_vector_distance  is_lemma  \
# 0                             None                     NaN      True
# 1                             None                     NaN      True
# 2                             None                     NaN      True
# 3                             None                     NaN      True
# 4                             None                0.339667      True
# ...                            ...                     ...       ...
# 123319                        None                     NaN      True
# 123320                        None                     NaN      True
# 123321                        None                     NaN      True
# 123322                        None                     NaN      True
# 123323                        None                     NaN      True
#
#        target_language_affix_match  morpheme_ranking
# 0                             True           3.86950
# 1                             True           4.52311
# 2                             True           5.32741
# 3                             True           5.76791
# 4                             True           6.75698
# ...                            ...               ...
# 123319                        None          30.29770
# 123320                        None          30.38920
# 123321                        None          30.48390
# 123322                        None               NaN
# 123323                        None               NaN
#
# [123324 rows x 15 columns]

# %% [markdown]
# and the featuredump output w/o cvd search for comparison

# %%
data_orig = analysis.dataframe_from_featuredump('sample-features-orig.json')

# %% [markdown]
# Here’s the current combined result survey sample.

# %%
analysis.survey()
# Out:
#             Query      Nêhiyawêwin 1          Nêhiyawêwin 2 Nêhiyawêwin 3
# 0           about              wayês                   ohci          papâ
# 1             all           kahkiyaw                   kapê        mâwaci
# 2            also               mîna                   êkwa         kisik
# 3             and               êkwa                   mîna         kisik
# 4              as              kisik                   wiya      tâpiskôt
# ..            ...                ...                    ...           ...
# 543  she sees him            wâpamêw                    NaN           NaN
# 544   starblanket         atâhkakohp  acâhkosa kâ-otakohpit           NaN
# 545  star blanket         atâhkakohp  acâhkosa kâ-otakohpit           NaN
# 546  being taught  kiskinwahamâkosiw                    NaN           NaN
# 547   they see us    niwâpamikonânak        kiwâpamikonawak           NaN
#
# [548 rows x 4 columns]

# %% [markdown]
# And `analysis.py` contains a function to annotate the `featuredump` results with the top3/three10 metrics.

# %%
analysis.top3_and_310_stats(data, rank_column="webapp_sort_rank")[
    ["query", "wordform_text", "definitions", "actual_result_ranks", "top3", "three10"]
]
# Out:
#                query wordform_text  \
# 0            "horse"       misatim
# 1            'horse'       misatim
# 2            Calgary   otôskwanihk
# 3               Cree       nêhiyaw
# 4      Cree language   nêhiyawêwin
# ..               ...           ...
# 543       yellow hat   osâwastotin
# 544              you          kiya
# 545            young          oski
# 546  younger sibling       nisîmis
# 547             your      kîstawâw
#
#                                            definitions actual_result_ranks  \
# 0                                        [[horse, CW]]         [4.0, 12.0]
# 1                                        [[horse, CW]]         [4.0, 13.0]
# 2    [[Calgary, AB; literally: at the elbow; at his...               [1.0]
# 3    [[A Cree Indian man. A native of the Cree nati...          [4.0, 5.0]
# 4    [[The Cree language., MD], [the Cree language;...               [4.0]
# ..                                                 ...                 ...
# 543                                 [[yellow hat, CW]]               [2.0]
# 544                            [[You., MD], [you, CW]]    [1.0, 4.0, 51.0]
# 545                                                NaN                  []
# 546  [[My younger brother or sister (Among children...               [3.0]
# 547                                                NaN          [6.0, 7.0]
#
#            top3     three10
# 0    100.000000   50.000000
# 1    100.000000   50.000000
# 2    100.000000  100.000000
# 3    100.000000  100.000000
# 4    100.000000  100.000000
# ..          ...         ...
# 543  100.000000  100.000000
# 544  100.000000   66.666667
# 545    0.000000    0.000000
# 546  100.000000  100.000000
# 547   66.666667   66.666667
#
# [548 rows x 6 columns]

# %% [markdown]
# ## Initial results from dictionary code

# %% [markdown]
# Without any cosine-vector stuff, here are the current search stats we want to beat. 81.3% for top3, and 59.4% for three10.

# %%
analysis.top3_and_310_stats_summary(data_orig, rank_column="webapp_sort_rank")
# Out:
# top3       81.326034
# three10    59.367397
# dtype: float64

# %% [markdown]
# Note: this won’t exactly match what the django `/search-quality` pages report, because of some differences in determining exactly what the rank is. In the django code, if the results are `(non-lemma1, non-lemma2)`, we count the ranks as `(1, 3)` because the UI display of `non-lemma1` includes its lemma definition at rank 2. Here we skip that for now, but the results should be close enough.

# %% [markdown]
# And, the stats when we add a very basic cosine vector distance model to the search:

# %%
analysis.top3_and_310_stats_summary(data, rank_column="webapp_sort_rank")
# Out:
# top3       83.424574
# three10    55.474453
# dtype: float64

# %% [markdown]
# The top3 score—what percent of desired search results we see anywhere in the list—has gone up. That is, the vector model’s ability to resolve synonyms has improved recall. But the three10 score—what percent of desired search results are near the top—has gone down since we don’t have a good ranking mechanism.

# %% [markdown]
# ## Modelling

# %%
def prep_results_for_regression(df):
    # In a straightforward linear combination, the default values won’t matter because
    # they get multiplied by the has_ variable which will be zero. But things could get
    # trickier if we have logarithms.
    return df.assign(
        morpheme_ranking=df["morpheme_ranking"].fillna(0),
        has_morpheme_ranking=analysis.has_col_as_int(df, "morpheme_ranking"),
        cosine_vector_distance=df["cosine_vector_distance"].fillna(1.1),
        has_cosine_vector_distance=analysis.has_col_as_int(df, "cosine_vector_distance"),
        is_in_survey=df.apply(analysis.is_in_survey, axis=1),
        keyword_match_len=data['target_language_keyword_match'].apply(len)
    )

# %%
df = prep_results_for_regression(data)
results = smf.ols(
    """
    is_in_survey ~
        wordform_length
        + keyword_match_len
        + has_morpheme_ranking
        + morpheme_ranking
        + np.log(1 + cosine_vector_distance)
    """,
    data=df,
).fit()
display(results.summary())
sorted_results = analysis.rank_by_predictor(df, results)
analysis.top3_and_310_stats_summary(sorted_results, rank_column="result_rank")
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           is_in_survey   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     1507.
# Date:                Tue, 04 May 2021   Prob (F-statistic):               0.00
# Time:                        09:42:06   Log-Likelihood:             1.3508e+05
# No. Observations:              123324   AIC:                        -2.701e+05
# Df Residuals:                  123318   BIC:                        -2.701e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              0.0554      0.003     19.471      0.000       0.050       0.061
# wordform_length                       -0.0006   9.35e-05     -6.066      0.000      -0.001      -0.000
# keyword_match_len                      0.0326      0.001     45.826      0.000       0.031       0.034
# has_morpheme_ranking                   0.0235      0.003      8.535      0.000       0.018       0.029
# morpheme_ranking                      -0.0010   6.76e-05    -14.739      0.000      -0.001      -0.001
# np.log(1 + cosine_vector_distance)    -0.1196      0.002    -79.101      0.000      -0.123      -0.117
# ==============================================================================
# Omnibus:                   197281.757   Durbin-Watson:                   1.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         80139050.180
# Skew:                          10.815   Prob(JB):                         0.00
# Kurtosis:                     125.996   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
# top3       83.424574
# three10    70.225061
# dtype: float64

# %%
x
# Out:
#    wordform_length  keyword_match_len  has_morpheme_ranking  morpheme_ranking  \
# 0                1                  0                     0                 0
#
#    cosine_vector_distance
# 0                       0

# %%
x = pd.DataFrame([
    {
        "wordform_length": 1,
        "keyword_match_len": 0,
        "has_morpheme_ranking": 0,
        "morpheme_ranking": 0,
        "cosine_vector_distance": 1.1,
    }
])
results.predict(x)
# Out:
# 0   -0.033908
# dtype: float64

# %%
x = pd.DataFrame([
    {
        "wordform_length": 1,
        "keyword_match_len": 0,
        "has_morpheme_ranking": 0,
        "morpheme_ranking": 0,
        "cosine_vector_distance": 0.7,
    }
])
results.predict(x)
# Out:
# 0   -0.00864
# dtype: float64

# %%
# This test is currently failing.
x = pd.DataFrame([
    {
        "wordform_length": 1,
        "keyword_match_len": 0,
        "has_morpheme_ranking": 1,
        "morpheme_ranking": 12.8,
        "cosine_vector_distance": 0.7,
    }
])
results.predict(x)
# Out:
# 0    0.002137
# dtype: float64

# %%
x = pd.DataFrame([
    {
        "wordform_length": 1,
        "keyword_match_len": 0,
        "has_morpheme_ranking": 1,
        "morpheme_ranking": 12.8,
        "cosine_vector_distance": 1.1,
    }
])
results.predict(x)[0]
# Out:
# -0.023130453155353087

# %%
results.params.values
# Out:
# array([ 0.05537813, -0.00056731,  0.03264485,  0.023535  , -0.00099665,
#        -0.11957764])

# %%
results.params.index
# Out:
# Index(['Intercept', 'wordform_length', 'keyword_match_len',
#        'has_morpheme_ranking', 'morpheme_ranking',
#        'np.log(1 + cosine_vector_distance)'],
#       dtype='object')

# %%
results.params.round(10)
# Out:
# Intercept                             0.055378
# wordform_length                      -0.000567
# keyword_match_len                     0.032645
# has_morpheme_ranking                  0.023535
# morpheme_ranking                     -0.000997
# np.log(1 + cosine_vector_distance)   -0.119578
# dtype: float64

# %%
sorted_results
# Out:
#        target_language_keyword_match  query_wordform_edit_distance  \
# 107652                        [hors]                           NaN
# 107660                        [hors]                           NaN
# 107676                        [hors]                           NaN
# 107668                        [hors]                           NaN
# 107662                        [hors]                           NaN
# ...                              ...                           ...
# 36080                             []                           NaN
# 36082                             []                           NaN
# 36079                             []                           NaN
# 36085                         [your]                           NaN
# 36107                         [your]                           NaN
#
#         lemma_wordform_text is_preverb_match source_language_match  \
# 107652              misatim             None                  None
# 107660             mistatim             None                  None
# 107676          misacimosis             None                  None
# 107668             nâpêstim             None                  None
# 107662           takahkatim             None                  None
# ...                     ...              ...                   ...
# 36080             kêtasâkêw             None                  None
# 36082           kâsîhkwâkêw             None                  None
# 36079   kisîpêkistikwânâkêw             None                  None
# 36085       mamisîtotamowin             None                  None
# 36107     kimosôm-pwâtinâhk             None                  None
#
#                                               definitions    query  \
# 107652                                      [[horse, CW]]  "horse"
# 107660                                  [[horse, CW, MD]]  "horse"
# 107676             [[little horse, pony, foal, colt, CW]]  "horse"
# 107668         [[stallion, male horse; male dog, CW, MD]]  "horse"
# 107662                       [[good horse; good dog, CW]]  "horse"
# ...                                                   ...      ...
# 36080   [[He takes his coat off., MD], [s/he takes his...     your
# 36082   [[s/he washes his/her own face with something,...     your
# 36079   [[s/he washes his/her own head with something,...     your
# 36085   [[The state oaf being confident in your faith ...     your
# 36107   [[Deschambeault Lake, SK; Woods Cree community...     your
#
#               wordform_text  webapp_sort_rank  wordform_length  ...  \
# 107652              misatim                 4                7  ...
# 107660             mistatim                12                8  ...
# 107676          misacimosis                28               11  ...
# 107668             nâpêstim                20                8  ...
# 107662           takahkatim                14               10  ...
# ...                     ...               ...              ...  ...
# 36080             kêtasâkêw                20                9  ...
# 36082           kâsîhkwâkêw                22               11  ...
# 36079   kisîpêkistikwânâkêw                19               19  ...
# 36085       mamisîtotamowin                25               15  ...
# 36107     kimosôm-pwâtinâhk                47               17  ...
#
#        cosine_vector_distance  is_lemma  target_language_affix_match  \
# 107652               0.000000      True                         None
# 107660               0.000000      True                         None
# 107676               0.138156      True                         None
# 107668               0.151773      True                         None
# 107662               0.183081      True                         None
# ...                       ...       ...                          ...
# 36080                0.459749      True                         None
# 36082                0.464270      True                         None
# 36079                0.456856      True                         None
# 36085                1.100000      True                         None
# 36107                1.100000      True                         None
#
#        morpheme_ranking  has_morpheme_ranking  has_cosine_vector_distance  \
# 107652          9.93681                     1                           1
# 107660         12.11330                     1                           1
# 107676         16.00270                     1                           1
# 107668         16.36890                     1                           1
# 107662         12.80170                     1                           1
# ...                 ...                   ...                         ...
# 36080          18.27890                     1                           1
# 36082          18.03480                     1                           1
# 36079          17.33790                     1                           1
# 36085          22.04670                     1                           0
# 36107          26.47440                     1                           0
#
#         is_in_survey  keyword_match_len     score  result_rank
# 107652             1                  1  0.097683          1.0
# 107660             1                  1  0.094947          2.0
# 107676             0                  1  0.073894          3.0
# 107668             0                  1  0.073809          4.0
# 107662             0                  1  0.073022          5.0
# ...              ...                ...       ...          ...
# 36080              0                  0  0.010358         43.0
# 36082              0                  0  0.009097         44.0
# 36079              0                  0  0.005860         45.0
# 36085              0                  1 -0.007644         46.0
# 36107              0                  1 -0.013191         47.0
#
# [123324 rows x 21 columns]

# %%
sorted_results.query("query == 'hair'")[
    ['wordform_text', 'definitions', 'morpheme_ranking',
     'has_cosine_vector_distance',
     'cosine_vector_distance', 'is_in_survey', 'score']
 ].head(10)
# Out:
#        wordform_text               definitions  morpheme_ranking  \
# 38211       mêstakay              [[hair, CW]]           13.5515
# 38215    miyahciwâna        [[pubic hair, CW]]           11.7409
# 38224  miyahciwânâna        [[pubic hair, CW]]           11.7409
# 38225       tipwêham   [[s/he curls hair, CW]]           14.3799
# 38212      mêscakâsa  [[hair; short hair, CW]]           16.2734
# 38213      mêscakâsa  [[hair; short hair, CW]]           16.2734
# 38214      mêscakâsa  [[hair; short hair, CW]]           16.2734
# 38223      mêscakâsa  [[hair; short hair, CW]]           16.2734
# 38226      nêstakaya           [[my hair, CW]]           12.1174
# 38227      nêstakaya           [[my hair, CW]]           12.1174
#
#        has_cosine_vector_distance  cosine_vector_distance  is_in_survey  \
# 38211                           1            5.960464e-08             0
# 38215                           1            1.552082e-01             0
# 38224                           1            1.552082e-01             0
# 38225                           1            1.693116e-01             0
# 38212                           1            1.481664e-01             1
# 38213                           1            1.481664e-01             1
# 38214                           1            1.481664e-01             1
# 38223                           1            1.481664e-01             1
# 38226                           1            1.924281e-01             0
# 38227                           1            1.924281e-01             0
#
#           score
# 38211  0.093513
# 38215  0.076363
# 38224  0.075229
# 38225  0.073984
# 38212  0.073712
# 38213  0.073712
# 38214  0.073712
# 38223  0.073712
# 38226  0.073331
# 38227  0.073331

# %%
sorted_results.query("query == 'yellow hat'")[
    ['wordform_text', 'definitions', 'morpheme_ranking',
     'has_cosine_vector_distance',
     'cosine_vector_distance', 'is_in_survey', 'score']
 ].head(10)
# Out:
#            wordform_text                                        definitions  \
# 110654       osâwastotin                                 [[yellow hat, CW]]
# 110705  nîpâmâyâtastotin                                 [[purple hat, CW]]
# 110661           astotin                         [[hat, cap, headgear, CW]]
# 110660          osâwêkin  [[Yellow cloth., MD], [yellow material; yellow...
# 110655        osâwasâkay                         [[yellow dress, coat, CW]]
# 110657            osâwi-                              [[yellow, brown, CW]]
# 110662     kayâs-astotin                                    [[old hat, CW]]
# 110663      piponastotin                                 [[winter hat, CW]]
# 110669            osâwâw  [[It is yellow., MD], [it is yellow; it is ora...
# 110664     iskwêwastotin                                [[woman's hat, CW]]
#
#         morpheme_ranking  has_cosine_vector_distance  cosine_vector_distance  \
# 110654          15.39000                           1                0.000000
# 110705          19.39890                           1                0.131871
# 110661           8.77879                           1                0.319382
# 110660          14.49420                           1                0.293730
# 110655          15.42040                           1                0.276213
# 110657          12.50920                           1                0.360646
# 110662          14.95230                           1                0.325223
# 110663          14.02940                           1                0.342403
# 110669          14.43830                           1                0.377142
# 110664          13.33950                           1                0.347781
#
#         is_in_survey     score
# 110654             1  0.122624
# 110705             0  0.068335
# 110661             0  0.065695
# 110660             0  0.061779
# 110655             0  0.061351
# 110657             0  0.058862
# 110662             0  0.055610
# 110663             0  0.055557
# 110669             0  0.055498
# 110664             0  0.055199

# %%
(data_orig.assign(is_in_survey=data_orig.apply(analysis.is_in_survey, axis=1))
 .query("query == 'hair'").sort_values('webapp_sort_rank')[
    ['wordform_text', 'definitions', 'morpheme_ranking', 'is_in_survey']
 ]).head(10)
# Out:
#         wordform_text                                        definitions  \
# 35464  pâhpakowêwayân                 [[hide with thick hair on it, CW]]
# 35465           pîway  [[hair from a hide, fur, bristles; feathers, p...
# 35466        mihyawê-                      [[with fur or body hair, CW]]
# 35467        mihyawê-                      [[with fur or body hair, CW]]
# 35468     miyahciwâna                                 [[pubic hair, CW]]
# 35469         wîcisiw               [[s/he has a good head of hair, CW]]
# 35470   miyahciwânâna                                 [[pubic hair, CW]]
# 35471         apihkêw  [[He knits. Or he braids. Could also mean he w...
# 35472       nêstakaya                                    [[my hair, CW]]
# 35473       nêstakaya                                    [[my hair, CW]]
#
#        morpheme_ranking  is_in_survey
# 35464           9.73725             0
# 35465          11.39430             1
# 35466          11.74090             0
# 35467          11.74090             0
# 35468          11.74090             0
# 35469          11.74090             0
# 35470          11.74090             0
# 35471          11.88350             0
# 35472          12.11740             0
# 35473          12.11740             0
